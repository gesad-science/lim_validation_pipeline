# %%
import pandas as pd

# %%
df = pd.read_csv('final_treated_dataset.csv')
df
# Out:
#         id                                           user_msg expected_intent  \
# 0        1  add student with name=anderson martins gomes, ...             ADD
# 1        2  add subject with name=brazilian history, descr...             ADD
# 2        3  add teacher with name=paulo henrique, age=65, ...             ADD
# 3        4  add subject with name=math, description=the be...             ADD
# 4        5  add subject with name=math, description='the b...             ADD
# ...    ...                                                ...             ...
# 1186  1187              add galaxy with current_redshift=0.01             ADD
# 1187  1188   add universe with cosmological_constant=positive             ADD
# 1188  1189             add instrument with case_included=true             ADD
# 1189  1190              add painting with condition=excellent             ADD
# 1190  1191   add sculpture with installation_location=outdoor             ADD
#
# ...

# %%
len(df['user_msg'].unique())
# Out:
# 1191

# %%
len(df[df['dataset']])
